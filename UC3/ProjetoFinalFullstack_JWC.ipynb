# %% [markdown]
# # **🔹 PROJETO FINAL FULL STACK - JWC TECH**

# %% [markdown]
# ![formacao-net.png.webp](data:image/webp;base64,...)

# %% [markdown]
# ###**Contexto**
#
# Vocês foram contratados como desenvolvedores em período de experiência na JWC Tech e devem desenvolver um projeto web completo (Front-end + Back-end) para um cliente. O *case* apresentado na primeira reunião de alinhamento é descrito a seguir:
#
#
# ---
#
# A empresa de Tecnologia JWC atua na área de desenvolvimento de aplicações web, atendendo diversos clientes de médio e grande porte. Sua sede está localizada no centro do Rio de Janeiro, com 30 colaboradores na área administrativa e 20 colaboradores na equipe de desenvolvimento, composta por diversos perfis.
#
# Com a pandemia, a empresa recebeu uma grande demanda, principalmente na área de educação. Com esse crescimento, o diretor identificou a necessidade de contratar novos programadores Full Stack. Quando recebeu a demanda de contratação, o departamento de Recursos Humanos propôs que o processo fosse feito em algumas etapas, nas quais os candidatos receberiam diversos desafios. Conforme a entrega de cada desafio, eles avançam para as etapas seguintes.
#
# O RH, então, publicou a seguinte vaga:
#
# **Programador Full Stack**
#
# *Buscamos pessoas desenvolvedoras de software que sejam curiosas, ágeis, inovadoras, apaixonadas por tecnologia e que buscam por uma melhoria contínua. É importante ter motivação para enfrentar desafios, proatividade e foco em criar experiências incríveis, em forma de software, para os nossos clientes.*
#
# Parabéns, você passou no processo seletivo e, agora, precisa passar pelo período de experiência.
#
# Durante esse período, você atenderá alguns clientes da JWC desenvolvendo um portfólio de aplicações Web – Front-end. Para isso, você deverá enfrentar alguns desafios apresentados nas aulas.
#
# ***Vamos juntos nessa jornada para conquistar a vaga definitiva de programador Full Stack?***
#
# ---

# %% [markdown]
# ### **Tecnologias**
#
# - **Front-end:** Node.js (servidor básico) + HTML/CSS + Bootstrap
# - **Back-end:** Python (Django REST Framework)
# - **Versionamento:** Git/GitHub
# - **Organização:** Trello/Notion

# %% [markdown]
# ### **📌 ETAPA 1: PESQUISA E DEFINIÇÃO DO PROJETO**
#
# 1. **Pesquisa de Mercado**
#
#    - Liste 3 possíveis sistemas web (ex.: e-commerce, agendamento online).
#    - Defina:
#      - Público-alvo;
#      - Principais funcionalidades.
#
# 2. **Pitch de Ideias**
#
#    - Apresentação rápida (3 min por grupo);
#    - Debatam as melhores propostas.

# %% [markdown]
# ### **📌 ETAPA 2: ESTRUTURA DO PROJETO**
#
# - Front-end:
#
# > Páginas essenciais (ex: Home, Cadastro, Dashboard);
#
# > Responsividade (mobile-first);
#
# > Consumo de API (embed code).
#
# - Back-end:
#
# > API REST (rotas para CRUD);
#
# > Banco de dados (SQLite/PostgreSQL/MySQL);
#
# > Autenticação (se necessário).

# %% [markdown]
# ###📌 ETAPA 3: DESENVOLVIMENTO (SPRINTS)
#
# Dividido em 4 sprints:
#
# | Sprint | Tarefas                              | Entregáveis                          |
# |--------|--------------------------------------|--------------------------------------|
# | 1      | Estrutura HTML + Bootstrap           | Páginas estáticas responsivas        |
# | 2      | API Django (CRUD)                    | Rotas GET/POST/PUT/DELETE            |
# | 3      | Integração Front+Back  | Dados dinâmicos no Front             |
# | 4      | Testes e ajustes                     | Sistema funcional e documentado      |

# %% [markdown]
# ###📌 ETAPA 4: ENTREGA FINAL
#
# Critérios de Avaliação:
#
# ✔ Funcionamento do sistema;
#
# ✔ Qualidade do código (organização, comentários);
#
# ✔ Design responsivo (Bootstrap);
#
# ✔ Trabalho em equipe (Git, divisão de tarefas).

# %% [markdown]
# ### Definição de Equipes:
#
# > (1) Iago Michael / Eduardo / Henzo / Andressa
#
# > (2) João Paulo / Alyfer / Carlos Eduardo
#
# > (3) Juan Carlo / Pablo / Renan / Pedro
#
# > (4) Artur / João Victor / Cesar / Andrei
#
# > (5) Breno / Cleiberson / Kaio / Luís / Wellington
